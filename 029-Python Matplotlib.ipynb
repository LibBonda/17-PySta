# %% [markdown]
# #### Matplotlib Tutorial
# - Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# - Matplotlib was created by John D. Hunter.
# - Matplotlib is open source and we can use it freely.
# - Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.
#
# ##### Installation
# - To install use:
#                 pip install matplotlib
#
# ##### Importing Matplotlib
# - To import use:
#                 import matplotlib
#
# ##### Check Version:
# - version string is  stored under __version__ attribute.

# %%
#install and import matplotlib
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.8.0

# %% [markdown]
# ##### Matplotlib Pyplot
# - Pyplot
# - Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 60])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #### Matplotlib Plotting
#
# ##### Plotting x and y points
# - The plot() function is used to draw points(markers) in a diagram.
# - By default, the plot() function draws a line from point to point.
# - The function takes parameters for specifying points in the diagram.
# - Parameter 1 is an array containing the points on the x-axis.
# - Parameter 2 is an array containing the points on the y-axis.

# %%
# Draw a line in a diagram from position (1, 3) to position (8, 10):
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ##### Plotting Without Line
# - To plot only the markers, use shortcut string notation parameter 'o', which means 'rings'.

# %%
#Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# ##### Multiple Points
# - It's possible to plot as many points as possible, just make sure you have the same number of points in both axis.

# %%
#Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ##### Default X-Points
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.

# %%
#Plotting without x-points:
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 9])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# #### Matplotlib Markers
#
# ##### Markers
# - Use keyword marker to emphasise each point with a specified marker

# %%
#Mark each point with a circle:
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1, 2, 3, 7, 12])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# #### Format Strings fmt
# - You can also use the shortcut string notation parameter to specify the marker.
# - This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
#Mark each point with a circle: use fmt marker|line|color
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')

# %% [markdown]
# #### Line Reference
# Line Syntax             Description
# '-'	                    Solid line
# ':'	                    Dotted line
# '--'	                Dashed line
# '-.'	                Dashed/dotted line
#
# #### Color Reference
# Color Syntax	        Description
# 'r'	                    Red
# 'g'	                    Green
# 'b'	                    Blue
# 'c'	                    Cyan
# 'm'	                    Magenta
# 'y'	                    Yellow
# 'k'	                    Black
# 'w'	                    White

# %% [markdown]
# #### Marker Size
# - You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %%
#Set the size of the markers to 20:
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 7, 10])

plt.plot(ypoints, marker = 'o', ms =15)
plt.show()

# %% [markdown]
# #### Marker Color
# - Use keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:

# %%
#Set the EDGE color to red:

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1, 2, 5, 9, 15, 25])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')

# %% [markdown]
# #### makrkerfacecolor
# - Use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %%
#Set the FACE color to red:
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
#Use both the mec and mfc arguments to color the entire marker:
#Set the color of both the edge and the face to red:

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# ##### Use Hexadecimal color values, or any of the 140 supported color names.:
# - Mark each point with a beautiful green color:

# %%
#plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o-.g', ms = 20, mec = '#4CAF50', mfc = 'hotpink')
plt.show()

# %% [markdown]
# #### Matplotlib Line
# - Use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:
#
# ##### Shorter Syntax
# - The line style can be written in a shorter syntax:
# - linestyle can be written as ls.
# - dotted can be written as :.
# - dashed can be written as --.

# %%
#Use a dotted line:
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([2, 7, 0, 9])
ypoints2 = np.array([3, 8, 1, 10])
ypoints3 = np.array([4, 9, 2, 11])

plt.plot(ypoints, linestyle = 'dotted', color = 'r')
plt.plot(ypoints2, ls = 'dashed', color = 'fuchsia')
plt.plot(ypoints3, ls = '-', color = 'yellowgreen')
plt.show()

# %% [markdown]
# #### Line Width
# - Use the keyword argument linewidth or the shorter lw to change the width of the line.
# - The value is a floating number, in points:

# %%
#Plot with 3 different widths 5pt, 10pt, 15pt wide line:

import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([2, 7, 0, 9])
ypoints2 = np.array([3, 8, 1, 10])
ypoints3 = np.array([4, 9, 2, 11])

plt.plot(ypoints, linestyle = 'dotted', color = 'r', linewidth = '5')
plt.plot(ypoints2, ls = 'dashed', color = 'fuchsia', lw = '10')
plt.plot(ypoints3, ls = '-', color = 'yellowgreen', lw = '15')
plt.show()

# %% [markdown]
# #### Plot as many lines as possible
# - Plot many lines by adding the points for the x- and y-axis for each line in the same plt.plot() function.
# - If only y-axis values are specified, the x-axis got the the default values (0, 1, 2, 3)
# - The x- and y- values come in pairs:

# %%
#Draw two lines by specifiyng the x- and y-point values for both lines:

import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# #### Matplotlib Labels and Title
# - Create Labels for a Plot
# - With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.
#
# #### Create a Title for a Plot
# With Pyplot, you can use the title() function to set a title for the plot.

# %%
#Add labels to the x- and y-axis:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y, color = 'r', ls = '--', ms = '5')

plt.title('Sports Watch Data')
plt.xlabel('Average Pulse')
plt.ylabel('Calorie Burnage')

plt.show()

# %% [markdown]
# #### Set Font Properties for Title and Labels
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
# Set font properties for the title and labels:
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'sans serif','color':'crimson','size':20}
font2 = {'family':'sans serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Position the Title
# - Use the loc parameter in title() to position the title.
# - Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
# Position the title to the left:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'sans serif','color':'crimson','size':10}
font2 = {'family':'sans serif','color':'darkred','size':10}

plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2, loc = 'center')
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Matplotlib Adding Grid
# - Use the grid() function to add grid lines to the plot

# %%
# Add gridlines to the plot:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'sans serif','color':'crimson','size':10}
font2 = {'family':'sans serif','color':'darkred','size':10}

plt.title("Sports Watch Data", fontdict = font1, loc = 'center')
plt.xlabel("Average Pulse", fontdict = font2, loc = 'center')
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# #### Specify Which Grid Lines to Display
# - Use the axis parameter in the grid() function to specify which grid lines to display.
# - Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
# Add gridlines to the plot:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'sans serif','color':'crimson','size':10}
font2 = {'family':'sans serif','color':'darkred','size':10}

plt.title("Sports Watch Data", fontdict = font1, loc = 'center')
plt.xlabel("Average Pulse", fontdict = font2, loc = 'center')
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# ##### Set Line Properties for the Grid
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).

# %%
# Add gridlines and set their properties to the plot:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'sans serif','color':'crimson','size':10}
font2 = {'family':'sans serif','color':'darkred','size':10}

plt.title("Sports Watch Data", fontdict = font1, loc = 'center')
plt.xlabel("Average Pulse", fontdict = font2, loc = 'center')
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(color = 'darkred', ls = '--', lw = 0.5)
plt.show()

# %% [markdown]
# #### Matplotlib Subplots
# ##### Display Multiple Plots
# With the subplot() function you can draw multiple plots in one figure:

# %%
# 2 plots
import matplotlib.pyplot as plt
import numpy as np

#plot 1

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)        #plt.subplot(1, 2, 1)
                            #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)        #plt.subplot(1, 2, 2)
                            #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)
plt.show()

# %% [markdown]
# #### if we want a figure with 2 rows and 1 column
# - (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %%
# Draw 2 plots on top of each other:
import matplotlib.pyplot as plt
import numpy as np

#plot 1

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)        #plt.subplot(2, 1, 1)
                            #the figure has 2 rows, 1 column, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)        #plt.subplot(2, 1, 2)
                            #the figure has 2 row, 1 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
# Draw 6 plots on top of each other:
import matplotlib.pyplot as plt
import numpy as np

#plot 1:

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)        #plt.subplot(2, 3, 1)
                            #the figure has 2 rows, 3 column, and this plot is the first plot.
plt.plot(x,y)
plt.title('Units')

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)        #plt.subplot(2, 3, 2)
                            #the figure has 2 row, 3 columns, and this plot is the second plot.
plt.plot(x,y)
plt.title('Sales')

#plot 3:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)        #plt.subplot(2, 3, 3)
                            #the figure has 2 rows, 3 column, and this plot is the thirdt plot.
plt.plot(x,y)
plt.title('Income')

#plot 4:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)        #plt.subplot(2, 3, 4)
                            #the figure has 2 rows, 2 columns, and this plot is the sfourth plot.
plt.plot(x,y)
plt.title('Household')

#plot 5:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)        #plt.subplot(2, 3, 4)
                            #the figure has 2 rows, 2 column, and this plot is the fifth plot.
plt.plot(x,y)
plt.title('National')

#plot 6:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)        #plt.subplot(2, 3, 6)
                            #the figure has 2 rows, 2 columns, and this plot is the sixth plot.

plt.plot(x,y)               #Title: You can add a title to each plot with the title() function:
plt.title('Regional')

plt.show()

# %% [markdown]
# #### Super Title
# - You can add a title to the entire figure with the suptitle() function:

# %%
# Add title for the entire figure
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

font1 = {'family':'sans serif','color':'crimson','size':10}
font2 = {'family':'sans serif','color':'darkred','size':10}

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES", fontdict = font1, loc = 'center')

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME", fontdict = font1, loc = 'center')

plt.suptitle("OUR SHOP")
plt.show()

# %% [markdown]
# #### Matplotlib Scatter
# Creating Scatter Plots
# - Use the scatter() function to draw a scatter plot.
# - The scatter() function plots one dot for each observation.
# - It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
#create a simple scatter plot:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.title("Vehicle Data", fontdict = font1, loc = 'center')
plt.xlabel("Age", fontdict = font2, loc = 'center')
plt.ylabel("Speed", fontdict = font2)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ##### Compare Plots
# -From the above, there seems to be a relationship between speed and age, but what if we plot the observations from another day as well?
# - Will the scatter plot tell us something else?

# %%
# Draw two plots on the same figure

import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# # conclusion:
# from the plots, it seems the newer the car, the higher the speed.

# %%
# Colors:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# #### Color Each Dot
# - It's possible to set a specific color for each dot by using an array of colors as value for the c argument:
#
# ##### Note:
# - You cannot use the color argument for this, only the c argument.

# %%
# Use own color markers

import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ##### ColorMap
# - The Matplotlib module has a number of available colormaps.
# - A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# - This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color.
#
# ##### How to Use the ColorMap
# - You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
# - In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
#Create a color array, and specify a colormap in the scatter plot:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c = colors, cmap = 'viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# #### Size (Marker)
# - You can change the size of the dots with the s argument.
# - Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %%
#set own marker sizes

import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c = colors, cmap = 'viridis', s = sizes, alpha = 0.5)        #Alpha: You can adjust the transparency of the dots with the alpha argument.
                                                                #Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

plt.show()

# %%
#combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:
#Create random arrays with 100 values for x-points, y-points, colors and sizes:

import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ##### Matplotlib Bars
# Create Bars With Pyplot, you can use the bar() function to draw bar graphs:
# The bar() function takes arguments that describes the layout of the bars.
# The categories and their values represented by the first and second argument as arrays.

# %%
#Draw 4 bars

import matplotlib.pyplot as plt
import numpy as np

plt.subplot(2, 1, 1)
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y, color = 'red', width = .75)            #bar() for vertical bars, add color and width
plt.show()

plt.subplot(2, 1, 2)
plt.barh(x, y, height = 0.5)           #barh() for horizontal bars use height for horizontal bars
plt.show()

# %% [markdown]
# #### Matplotlib Histograms
# - A histogram is a graph showing frequency distributions.
# - It is a graph showing the number of observations within each given interval.
# - Use the hist() function to create histograms
# - the hist() will use an array of numbers to create a histogram. the array is sent into the function as an argument

# %%
#A normal Data Distribution by NumPy:

import numpy as np
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [162.61221493 163.13623119 163.02453842 181.14498291 173.26660488
#  160.1210097  167.804134   171.4449885  163.14371698 175.14116665
#  180.84274884 167.18739092 179.03745829 163.21761837 170.7825872
#  177.04717052 185.93695409 147.87630884 173.61281577 171.28383771
#  154.2317745  156.39927582 182.41650382 166.235396   176.28423557
#  167.73702124 169.77400496 180.90496983 152.96876791 176.39922088
#  149.02729248 161.60031227 168.99561986 164.83361801 170.01965504
#  169.70972744 165.26668204 162.9674506  183.65164664 151.80334233
#  170.74830471 167.74348828 180.29063849 158.13746633 156.28620331
#  161.61157064 180.82297673 159.05018626 151.46216409 178.99290584
#  162.3398511  180.71931988 165.94774222 156.12124955 162.49382217
#  162.26639922 182.6150706  153.78387986 172.38364531 178.33979449
#  181.68145668 161.6698758  156.45675983 154.65416799 163.02621013
#  170.4051667  165.33527555 179.86361328 170.2677851  160.31102197
# ...

# %%
#create a simple histogram
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)

plt.show()

# %% [markdown]
# #### Matplotlib Pie Charts
# - With Pyplot, you can use the pie() function to draw pie charts:
# - Note: The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#         The value divided by the sum of all values: x/sum(x)

# %%
#A simple Pie Chart

import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

#add labels
mylabels = ['Apples', 'Berries', 'Cherries', 'Dates']

plt.pie(y, labels = mylabels)
plt.show()

# %%
#the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#The startangle parameter is defined with an angle in degrees, default angle is 0:

#Start the first wedge at 90 degrees:

import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ['Apples', 'Berries', "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# ##### Explode
# - If needed to make oneof the wedges to stand out? The explode parameter allows you to do that.
# - The explode parameter, if specified, and not None, must be an array with one value for each wedge.
# - Each value represents how far from the center each wedge is displayed:

# %%
#Pull the "Apples" wedge 0.2 from the center of the pie:

import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Berries", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True) #Add a shadow by seteing the shadows parameter to True
plt.show()

# %% [markdown]
# ##### Colors
# - Set the color of each wedge with the colors parameter.
# - The colors parameter, if specified, must be an array with one value for each wedge:

# %%
#Specify a new color for each wedge:

import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["gray", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)

#Legend: To add a list of explanation for each wedge, use the legend() function, add a header to the legend as well
plt.legend(title = "Four Fruits", loc = 'right')
plt.show()
